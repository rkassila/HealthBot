# %%
import pandas as pd
import os

# %%
path = "databases/diseases/dataset.csv"
diseases_df = pd.read_csv(os.path.join("..", path))

# %%
diseases_df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
input_symptoms = ['itching', 'skin_rash']

# %%
def check_symptoms(row, symptoms):
    row_symptoms = row.dropna().str.strip().tolist()  # Drop NaN values, strip whitespace, and convert to list
    return all(symptom in row_symptoms for symptom in symptoms)

# %%
matched_diseases = diseases_df[diseases_df.apply(check_symptoms, symptoms=input_symptoms, axis=1)]

# %%
print(input_symptoms)
matched_diseases
# Out:
# ['itching', 'skin_rash']
#                Disease Symptom_1   Symptom_2              Symptom_3  \
# 0     Fungal infection   itching   skin_rash   nodal_skin_eruptions
# 3     Fungal infection   itching   skin_rash    dischromic _patches
# 4     Fungal infection   itching   skin_rash   nodal_skin_eruptions
# 7     Fungal infection   itching   skin_rash    dischromic _patches
# 8     Fungal infection   itching   skin_rash   nodal_skin_eruptions
# ...                ...       ...         ...                    ...
# 4842     Drug Reaction   itching   skin_rash           stomach_pain
# 4854       Chicken pox   itching   skin_rash                fatigue
# 4879  Fungal infection   itching   skin_rash   nodal_skin_eruptions
# 4883     Drug Reaction   itching   skin_rash           stomach_pain
# 4895       Chicken pox   itching   skin_rash                fatigue
#
#                  Symptom_4             Symptom_5  Symptom_6  \
# 0      dischromic _patches                   NaN        NaN
# ...
